# %%
import pandas as pd
df = pd.read_csv('patients_sample_50.csv')
df
# Out:
#    patient_id first_name last_name         dob                        email  \
# 0        P001     Sakshi     Mehta  1967-09-13     sakshi.mehta229@mail.com
# 1        P002      Pooja    Pujari  1986-12-12  pooja.pujari550@example.com
# 2        P003      Anika     Desai  1969-12-12     anika.desai948@health.io
# 3        P004      Harsh  Bhandari  1955-07-26   harsh.bhandari157@mail.com
# 4        P005     Sakshi   Mahajan  1959-06-11   sakshi.mahajan383@mail.com
# 5        P006      Nisha      Kate  1981-07-11       nisha.kate688@test.org
# 6        P007      Vikas       Rao  1982-08-11     vikas.rao479@example.com
# 7        P008      Tanvi     Joshi  1945-12-03      tanvi.joshi400@test.org
# 8        P009     Ishaan    Tekade  2001-04-18      ishaan.tekade84@demo.co
# 9        P010       Ansh     Pawar  2005-08-24      ansh.pawar837@health.io
# 10       P011       Ansh       Rao  1955-10-07          ansh.rao78@mail.com
# ...
